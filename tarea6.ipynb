# %% [markdown]
# <a href="https://colab.research.google.com/github/Alejandrico14/Dise-o-y-Analisis-de-Algoritmos/blob/main/tarea6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class NodoArbol:
    def __init__( self , value , left=None , right=None ):
        self.data = value
        self.left = left
        self.right = right

class ArbolBinarioBusqueda:
    def __init__( self ):
        self.__root = None
    
    def insert( self , value ):
        if self.__root == None:
            self.__root = NodoArbol( value )
        else:
            self.__insert__( self.__root , value )

    def __insert__( self , nodo , value ): # recursividad
        if nodo.data == value :
            print("El nodo ya existe, no se inserta: " , value)
        elif value < nodo.data:
            # ir a la izq
            if nodo.left == None:
                nodo.left = NodoArbol( value , None , None )
            else:
                self.__insert__( nodo.left , value  )
        else:
            #ir a la derecha 
            if nodo.right == None:
                nodo.right = NodoArbol( value , None , None )
            else:
                self.__insert__( nodo.right , value )


    def transversal( self , format="in" ): # in, pos , pre
        if format=="in":
            print("\n Recorrido in")
            self.__recorrido_in( self.__root )
        elif format=="pre":
            print("\nRecorrido en pre orden")
            self.__recorrido_pre( self.__root )
        elif format == "pozole":
            print("\nRecorrido en pos orden")
            self.__recorrido_pos( self.__root )
        else:
            print("Formato no válido")

    def __recorrido_in( self , nodo ):
        if nodo == None:
            #print("Caso base")
            pass
        else:
            self.__recorrido_in( nodo.left )
            print(nodo.data , end=",")
            self.__recorrido_in( nodo.right )
    
    def __recorrido_pos( self , nodo ):
        if nodo == None:
            #print("Caso base")
            pass
        else:
            self.__recorrido_pos( nodo.left )
            self.__recorrido_pos( nodo.right )  
            print(nodo.data , end=",")         
        
    def __recorrido_pre( self , nodo ):
        if nodo == None:
            #print("Caso base")
            pass
        else:
            print(nodo.data , end=",")
            self.__recorrido_pre( nodo.left )
            self.__recorrido_pre( nodo.right )
    
    def search( self , value ):
        if self.__root == None:
            print("Árbol vacío")
        else:
            return self.__search( self.__root  , value )
    
    def __search( self , nodo , value ):
        if nodo == None:
            return None
        elif nodo.data == value:
            return nodo
        elif value < nodo.data:
            print("Ir a la izquierda")
            return self.__search( nodo.left , value )
        else:
            print("ir a la derecha")
            return self.__search( nodo.right , value  )

    def remove( self , value ):
        if self.__root == None:
            print("Árbol vacío")
# se borra la raíz aqui
        else:
            self.__remove( None, None  , self.__root , value )

    def __remove( self , padre_hijo , padre_en_hd , actual , value ):
        if actual == None:
            print("Caso base")
            return None
        elif actual.data == value:
            print("\n \n aki ta el numero solicitado " , actual.data )
# el caso es cuando el nodo es hoja
            if actual.left == None and actual.right == None:
                if padre_hijo != None:
                    padre_hijo.left =None
                else:
                    padre_en_hd.right = None
# caso 2, ps tiene 1 chamaco el nodo owo

            elif (actual.left != None and actual.right ==None) or (actual.left == None and actual.right !=None):
                if actual.left != None:  
                    print("Arriba Izquierda")
                    aux = actual.left
                    actual.left = None
                    actual = aux
                else:
                    print("arriba Derecha")
                    aux = actual.right
                    actual.right = None
                    actual = aux

            #caso 3: Tiene los dos hijos

        elif value < actual.data:
            self.__remove( actual , None , actual.left , value )
        else:
            self.__remove( None , actual , actual.right , value )

# %%
abb = ArbolBinarioBusqueda()
abb.insert( 55 )
abb.insert( 70 )
abb.insert( 45 )
abb.insert( 20 )
abb.insert( 29 )

abb.insert( 4)
abb.insert( 14 )
abb.insert( 1000 )

abb.transversal("in")
abb.transversal("pre")
abb.transversal("pozole")

abb.transversal()

abb.remove(55)
abb.transversal()
# Out:
#  Recorrido in
# 4,14,20,29,45,55,70,1000,
# Recorrido en pre orden
# 55,45,20,4,14,29,70,1000,
# Recorrido en pos orden
# 14,4,29,20,45,1000,70,55,
#  Recorrido in
# 4,14,20,29,45,55,70,1000,
#
#  aki ta el Numero  55
#
#  Recorrido in
# 4,14,20,29,45,55,70,1000,
